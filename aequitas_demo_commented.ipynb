# %%
import sys
# !{sys.executable} -m pip install aequitas==0.42 pandas==1.2.3
# Out:
# Collecting aequitas==0.42
#   Using cached aequitas-0.42.0-py3-none-any.whl (2.2 MB)
# Collecting pandas==1.2.3
#   Downloading pandas-1.2.3-cp39-cp39-macosx_10_9_x86_64.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 5.7 MB/s eta 0:00:01
# Collecting tabulate==0.8.2
#   Using cached tabulate-0.8.2-py3-none-any.whl
# Collecting xhtml2pdf==0.2.2
#   Using cached xhtml2pdf-0.2.2-py3-none-any.whl
# Requirement already satisfied: matplotlib>=3.0.3 in /opt/anaconda3/lib/python3.9/site-packages (from aequitas==0.42) (3.4.3)
# Requirement already satisfied: SQLAlchemy>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from aequitas==0.42) (1.4.22)
# Requirement already satisfied: seaborn>=0.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from aequitas==0.42) (0.11.2)
# Collecting millify==0.1.1
#   Using cached millify-0.1.1-py3-none-any.whl
# Collecting ohio>=0.2.0
#   Using cached ohio-0.5.0-py3-none-any.whl (26 kB)
# Collecting altair==4.1.0
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting markdown2==2.3.5
#   Using cached markdown2-2.3.5-py3-none-any.whl
# Collecting Flask==0.12.2
#   Using cached Flask-0.12.2-py2.py3-none-any.whl (83 kB)
# Collecting Flask-Bootstrap==3.3.7.1
#   Using cached Flask_Bootstrap-3.3.7.1-py3-none-any.whl
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from aequitas==0.42) (6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas==1.2.3) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.9/site-packages (from pandas==1.2.3) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas==1.2.3) (2021.3)
# Requirement already satisfied: entrypoints in /opt/anaconda3/lib/python3.9/site-packages (from altair==4.1.0->aequitas==0.42) (0.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from altair==4.1.0->aequitas==0.42) (2.11.3)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.9/site-packages (from altair==4.1.0->aequitas==0.42) (0.11.1)
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.9/site-packages (from altair==4.1.0->aequitas==0.42) (3.2.0)
# Requirement already satisfied: itsdangerous>=0.21 in /opt/anaconda3/lib/python3.9/site-packages (from Flask==0.12.2->aequitas==0.42) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/anaconda3/lib/python3.9/site-packages (from Flask==0.12.2->aequitas==0.42) (2.0.2)
# Requirement already satisfied: click>=2.0 in /opt/anaconda3/lib/python3.9/site-packages (from Flask==0.12.2->aequitas==0.42) (8.0.3)
# Collecting visitor
#   Using cached visitor-0.1.3-py3-none-any.whl
# Collecting dominate
#   Using cached dominate-2.6.0-py2.py3-none-any.whl (29 kB)
# Collecting httplib2
#   Using cached httplib2-0.20.4-py3-none-any.whl (96 kB)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (1.16.0)
# Collecting pyPdf2
#   Downloading PyPDF2-2.2.0-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 5.6 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.9/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (8.4.0)
# Collecting reportlab>=3.0
#   Downloading reportlab-3.6.10-cp39-cp39-macosx_10_9_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: html5lib>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (1.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.9/site-packages (from html5lib>=1.0->xhtml2pdf==0.2.2->aequitas==0.42) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->altair==4.1.0->aequitas==0.42) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (0.10.0)
# Collecting Pillow
#   Downloading Pillow-9.1.1-cp39-cp39-macosx_10_10_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 10.5 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from seaborn>=0.9.0->aequitas==0.42) (1.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.1.1->aequitas==0.42) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (21.2.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.9/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (0.18.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.9/site-packages (from pyPdf2->xhtml2pdf==0.2.2->aequitas==0.42) (3.10.0.2)
# Installing collected packages: Pillow, visitor, reportlab, pyPdf2, pandas, httplib2, Flask, dominate, xhtml2pdf, tabulate, ohio, millify, markdown2, Flask-Bootstrap, altair, aequitas
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.2
#     Uninstalling Flask-1.1.2:
#       Successfully uninstalled Flask-1.1.2
# Successfully installed Flask-0.12.2 Flask-Bootstrap-3.3.7.1 Pillow-9.1.1 aequitas-0.42.0 altair-4.1.0 dominate-2.6.0 httplib2-0.20.4 markdown2-2.3.5 millify-0.1.1 ohio-0.5.0 pandas-1.2.3 pyPdf2-2.2.0 reportlab-3.6.10 tabulate-0.8.2 visitor-0.1.3 xhtml2pdf-0.2.2

# %%
import pandas as pd
from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness
import aequitas.plot as ap

# Enable Pandas to display dataframes without restriction.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Load in the data and take an initial look at it.
df = pd.read_csv("data/compas_for_aequitas.csv")
print(df.shape)
df.head()
# Out:
# (7214, 6)
#    entity_id  score  label_value              race   sex          age_cat
# 0          1    0.0            0             Other  Male  Greater than 45
# 1          3    0.0            1  African-American  Male          25 - 45
# 2          4    0.0            1  African-American  Male     Less than 25
# 3          5    1.0            0  African-American  Male     Less than 25
# 4          6    0.0            0             Other  Male          25 - 45

# %%
# Race is our protected class that we will be exploring.
df["race"].value_counts()
# Out:
# African-American    3696
# Caucasian           2454
# Hispanic             637
# Other                377
# Asian                 32
# Native American       18
# Name: race, dtype: int64

# %%
# Remove the races that have very little data in this data.
df = df[~df["race"].isin(["Asian", "Native American"])]

# %% [markdown]
# ### Create Crosstab
#
# Create the crosstab that forms the basis for all the subsequent analyses.

# %%
group = Group()
xtab, _ = group.get_crosstabs(df)

xtab.head(10)
# Out:
#    model_id score_threshold     k attribute_name   attribute_value       tpr  \
# 0         0      binary 0/1  3297           race  African-American  0.720147
# 1         0      binary 0/1  3297           race         Caucasian  0.522774
# 2         0      binary 0/1  3297           race          Hispanic  0.443966
# 3         0      binary 0/1  3297           race             Other  0.323308
# 4         0      binary 0/1  3297            sex            Female  0.607287
# 5         0      binary 0/1  3297            sex              Male  0.628196
# 6         0      binary 0/1  3297        age_cat           25 - 45  0.625399
# 7         0      binary 0/1  3297        age_cat   Greater than 45  0.424797
# 8         0      binary 0/1  3297        age_cat      Less than 25  0.738928
#
#         tnr       for       fdr       fpr       fnr       npv  precision  \
# 0  0.551532  0.349540  0.370285  0.448468  0.279853  0.650460   0.629715
# 1  0.765457  0.288125  0.408665  0.234543  0.477226  0.711875   0.591335
# 2  0.785185  0.288591  0.457895  0.214815  0.556034  0.711409   0.542105
# 3  0.852459  0.302013  0.455696  0.147541  0.676692  0.697987   0.544304
# 4  0.678212  0.242197  0.489796  0.321788  0.392713  0.757803   0.510204
# 5  0.674350  0.332029  0.365079  0.325650  0.371804  0.667971   0.634921
# 6  0.665607  0.324885  0.384736  0.334393  0.374601  0.675115   0.615264
# 7  0.830841  0.241468  0.464103  0.169159  0.575203  0.758532   0.535897
# 8  0.455371  0.426667  0.362173  0.544629  0.261072  0.573333   0.637827
#
#      pp    pn       ppr     pprev   fp    fn    tn    tp  group_label_pos  \
# 0  2174  1522  0.659387  0.588203  805   532   990  1369             1901
# 1   854  1600  0.259023  0.348003  349   461  1139   505              966
# 2   190   447  0.057628  0.298273   87   129   318   103              232
# 3    79   298  0.023961  0.209549   36    90   208    43              133
# 4   588   801  0.178344  0.423326  288   194   607   300              494
# 5  2709  3066  0.821656  0.469091  989  1018  2048  1720             2738
# 6  1913  2170  0.580224  0.468528  736   705  1465  1177             1882
# 7   390  1172  0.118289  0.249680  181   283   889   209              492
# 8   994   525  0.301486  0.654378  360   224   301   634              858
#
#    group_label_neg  group_size  total_entities      prev
# 0             1795        3696            7164  0.514340
# 1             1488        2454            7164  0.393643
# 2              405         637            7164  0.364207
# 3              244         377            7164  0.352785
# 4              895        1389            7164  0.355652
# 5             3037        5775            7164  0.474113
# 6             2201        4083            7164  0.460936
# 7             1070        1562            7164  0.314981
# 8              661        1519            7164  0.564845

# %% [markdown]
# Abbev. | Name
# --- | ---
# tpr | True Positive Rate
# tnr | True Negative Rate
# for |False Omission Rate
# fdr | False Discovery Rate
# fpr | False Positive Rate
# fnr | False Negative Rate
# npv | Negative Predictive Value
# pp | Predicted Positive Count
# pn | Predicted Negative Count
# ppr | Predicted Positive Ratio_k
# pprev | Predicted Positive Ratio_g
# fp | False Postives
# fn | False Negatives
# tn | True Negatives
# tp | True Positives
# prev | Group Prevalance

# %% [markdown]
# ### Compute Bias
#
# We calculate the bias vs. a predefined group we manually set.

# %%
bias = Bias()
bias_df = bias.get_disparity_predefined_groups(xtab,
                                               original_df=df,
                                               ref_groups_dict={"race": "Caucasian", "sex": "Male", "age_cat": "25 - 45"},
                                               alpha=0.05,
                                               mask_significance=True)
bias_df.head(10)
# Out:
# get_disparity_predefined_group()
#    model_id score_threshold     k attribute_name   attribute_value       tpr  \
# 0         0      binary 0/1  3297           race  African-American  0.720147
# 1         0      binary 0/1  3297           race         Caucasian  0.522774
# 2         0      binary 0/1  3297           race          Hispanic  0.443966
# 3         0      binary 0/1  3297           race             Other  0.323308
# 4         0      binary 0/1  3297            sex            Female  0.607287
# 5         0      binary 0/1  3297            sex              Male  0.628196
# 6         0      binary 0/1  3297        age_cat           25 - 45  0.625399
# 7         0      binary 0/1  3297        age_cat   Greater than 45  0.424797
# 8         0      binary 0/1  3297        age_cat      Less than 25  0.738928
#
#         tnr       for       fdr       fpr       fnr       npv  precision  \
# 0  0.551532  0.349540  0.370285  0.448468  0.279853  0.650460   0.629715
# 1  0.765457  0.288125  0.408665  0.234543  0.477226  0.711875   0.591335
# 2  0.785185  0.288591  0.457895  0.214815  0.556034  0.711409   0.542105
# 3  0.852459  0.302013  0.455696  0.147541  0.676692  0.697987   0.544304
# 4  0.678212  0.242197  0.489796  0.321788  0.392713  0.757803   0.510204
# 5  0.674350  0.332029  0.365079  0.325650  0.371804  0.667971   0.634921
# 6  0.665607  0.324885  0.384736  0.334393  0.374601  0.675115   0.615264
# 7  0.830841  0.241468  0.464103  0.169159  0.575203  0.758532   0.535897
# 8  0.455371  0.426667  0.362173  0.544629  0.261072  0.573333   0.637827
#
#      pp    pn       ppr     pprev   fp    fn    tn    tp  group_label_pos  \
# 0  2174  1522  0.659387  0.588203  805   532   990  1369             1901
# 1   854  1600  0.259023  0.348003  349   461  1139   505              966
# 2   190   447  0.057628  0.298273   87   129   318   103              232
# 3    79   298  0.023961  0.209549   36    90   208    43              133
# 4   588   801  0.178344  0.423326  288   194   607   300              494
# 5  2709  3066  0.821656  0.469091  989  1018  2048  1720             2738
# 6  1913  2170  0.580224  0.468528  736   705  1465  1177             1882
# 7   390  1172  0.118289  0.249680  181   283   889   209              492
# 8   994   525  0.301486  0.654378  360   224   301   634              858
#
#    group_label_neg  group_size  total_entities      prev  ppr_disparity  \
# 0             1795        3696            7164  0.514340       2.545667
# 1             1488        2454            7164  0.393643       1.000000
# 2              405         637            7164  0.364207       0.222482
# 3              244         377            7164  0.352785       0.092506
# 4              895        1389            7164  0.355652       0.217054
# 5             3037        5775            7164  0.474113       1.000000
# 6             2201        4083            7164  0.460936       1.000000
# 7             1070        1562            7164  0.314981       0.203868
# 8              661        1519            7164  0.564845       0.519603
#
#    pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0         1.690224             1.064904       0.906085       1.213154
# 1         1.000000             1.000000       1.000000       1.000000
# 2         0.857099             0.916748       1.120464       1.001616
# 3         0.602147             0.920466       1.115085       1.048203
# 4         0.902439             0.803571       1.341615       0.729447
# 5         1.000000             1.000000       1.000000       1.000000
# 6         1.000000             1.000000       1.000000       1.000000
# 7         0.532903             0.871004       1.206288       0.743241
# 8         1.396667             1.036672       0.941355       1.313286
#
#    fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0       1.912093       0.586416       1.377549       0.720526       0.913728
# 1       1.000000       1.000000       1.000000       1.000000       1.000000
# 2       0.915887       1.165140       0.849249       1.025773       0.999346
# 3       0.629057       1.417970       0.618447       1.113660       0.980490
# 4       0.988139       1.056235       0.966717       1.005728       1.134484
# 5       1.000000       1.000000       1.000000       1.000000       1.000000
# 6       1.000000       1.000000       1.000000       1.000000       1.000000
# 7       0.505868       1.535507       0.679242       1.248247       1.123560
# 8       1.628708       0.696933       1.181531       0.684144       0.849238
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0           Caucasian             Caucasian                 Caucasian
# 1           Caucasian             Caucasian                 Caucasian
# 2           Caucasian             Caucasian                 Caucasian
# 3           Caucasian             Caucasian                 Caucasian
# 4                Male                  Male                      Male
# 5                Male                  Male                      Male
# 6             25 - 45               25 - 45                   25 - 45
# 7             25 - 45               25 - 45                   25 - 45
# 8             25 - 45               25 - 45                   25 - 45
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0           Caucasian           Caucasian           Caucasian
# 1           Caucasian           Caucasian           Caucasian
# 2           Caucasian           Caucasian           Caucasian
# 3           Caucasian           Caucasian           Caucasian
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0           Caucasian           Caucasian           Caucasian
# 1           Caucasian           Caucasian           Caucasian
# 2           Caucasian           Caucasian           Caucasian
# 3           Caucasian           Caucasian           Caucasian
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   npv_ref_group_value
# 0           Caucasian
# 1           Caucasian
# 2           Caucasian
# 3           Caucasian
# 4                Male
# 5                Male
# 6             25 - 45
# 7             25 - 45
# 8             25 - 45

# %% [markdown]
# Another common option:

# %%
bias.get_disparity_major_group(xtab,
                               original_df=df,
                               alpha=0.05,
                               mask_significance=True).head(10)
# Out:
# get_disparity_major_group()
#    model_id score_threshold     k attribute_name   attribute_value       tpr  \
# 0         0      binary 0/1  3297           race  African-American  0.720147
# 1         0      binary 0/1  3297           race         Caucasian  0.522774
# 2         0      binary 0/1  3297           race          Hispanic  0.443966
# 3         0      binary 0/1  3297           race             Other  0.323308
# 4         0      binary 0/1  3297            sex            Female  0.607287
# 5         0      binary 0/1  3297            sex              Male  0.628196
# 6         0      binary 0/1  3297        age_cat           25 - 45  0.625399
# 7         0      binary 0/1  3297        age_cat   Greater than 45  0.424797
# 8         0      binary 0/1  3297        age_cat      Less than 25  0.738928
#
#         tnr       for       fdr       fpr       fnr       npv  precision  \
# 0  0.551532  0.349540  0.370285  0.448468  0.279853  0.650460   0.629715
# 1  0.765457  0.288125  0.408665  0.234543  0.477226  0.711875   0.591335
# 2  0.785185  0.288591  0.457895  0.214815  0.556034  0.711409   0.542105
# 3  0.852459  0.302013  0.455696  0.147541  0.676692  0.697987   0.544304
# 4  0.678212  0.242197  0.489796  0.321788  0.392713  0.757803   0.510204
# 5  0.674350  0.332029  0.365079  0.325650  0.371804  0.667971   0.634921
# 6  0.665607  0.324885  0.384736  0.334393  0.374601  0.675115   0.615264
# 7  0.830841  0.241468  0.464103  0.169159  0.575203  0.758532   0.535897
# 8  0.455371  0.426667  0.362173  0.544629  0.261072  0.573333   0.637827
#
#      pp    pn       ppr     pprev   fp    fn    tn    tp  group_label_pos  \
# 0  2174  1522  0.659387  0.588203  805   532   990  1369             1901
# 1   854  1600  0.259023  0.348003  349   461  1139   505              966
# 2   190   447  0.057628  0.298273   87   129   318   103              232
# 3    79   298  0.023961  0.209549   36    90   208    43              133
# 4   588   801  0.178344  0.423326  288   194   607   300              494
# 5  2709  3066  0.821656  0.469091  989  1018  2048  1720             2738
# 6  1913  2170  0.580224  0.468528  736   705  1465  1177             1882
# 7   390  1172  0.118289  0.249680  181   283   889   209              492
# 8   994   525  0.301486  0.654378  360   224   301   634              858
#
#    group_label_neg  group_size  total_entities      prev  ppr_disparity  \
# 0             1795        3696            7164  0.514340       1.000000
# 1             1488        2454            7164  0.393643       0.392824
# 2              405         637            7164  0.364207       0.087397
# 3              244         377            7164  0.352785       0.036339
# 4              895        1389            7164  0.355652       0.217054
# 5             3037        5775            7164  0.474113       1.000000
# 6             2201        4083            7164  0.460936       1.000000
# 7             1070        1562            7164  0.314981       0.203868
# 8              661        1519            7164  0.564845       0.519603
#
#    pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0         1.000000             1.000000       1.000000       1.000000
# 1         0.591638             0.939052       1.103650       0.824297
# 2         0.507092             0.860874       1.236600       0.825630
# 3         0.356253             0.864366       1.230663       0.864031
# 4         0.902439             0.803571       1.341615       0.729447
# 5         1.000000             1.000000       1.000000       1.000000
# 6         1.000000             1.000000       1.000000       1.000000
# 7         0.532903             0.871004       1.206288       0.743241
# 8         1.396667             1.036672       0.941355       1.313286
#
#    fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0       1.000000       1.000000       1.000000       1.000000       1.000000
# 1       0.522987       1.705274       0.725927       1.387874       1.094418
# 2       0.478997       1.986883       0.616493       1.423644       1.093702
# 3       0.328989       2.418028       0.448947       1.545620       1.073066
# 4       0.988139       1.056235       0.966717       1.005728       1.134484
# 5       1.000000       1.000000       1.000000       1.000000       1.000000
# 6       1.000000       1.000000       1.000000       1.000000       1.000000
# 7       0.505868       1.535507       0.679242       1.248247       1.123560
# 8       1.628708       0.696933       1.181531       0.684144       0.849238
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0    African-American      African-American          African-American
# 1    African-American      African-American          African-American
# 2    African-American      African-American          African-American
# 3    African-American      African-American          African-American
# 4                Male                  Male                      Male
# 5                Male                  Male                      Male
# 6             25 - 45               25 - 45                   25 - 45
# 7             25 - 45               25 - 45                   25 - 45
# 8             25 - 45               25 - 45                   25 - 45
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0    African-American    African-American    African-American
# 1    African-American    African-American    African-American
# 2    African-American    African-American    African-American
# 3    African-American    African-American    African-American
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0    African-American    African-American    African-American
# 1    African-American    African-American    African-American
# 2    African-American    African-American    African-American
# 3    African-American    African-American    African-American
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   npv_ref_group_value
# 0    African-American
# 1    African-American
# 2    African-American
# 3    African-American
# 4                Male
# 5                Male
# 6             25 - 45
# 7             25 - 45
# 8             25 - 45

# %%
fairness = Fairness()
fairness_df = fairness.get_group_value_fairness(bias_df)
fairness_df.head(10)
# Out:
#    model_id score_threshold     k attribute_name   attribute_value       tpr  \
# 0         0      binary 0/1  3297           race  African-American  0.720147
# 1         0      binary 0/1  3297           race         Caucasian  0.522774
# 2         0      binary 0/1  3297           race          Hispanic  0.443966
# 3         0      binary 0/1  3297           race             Other  0.323308
# 4         0      binary 0/1  3297            sex            Female  0.607287
# 5         0      binary 0/1  3297            sex              Male  0.628196
# 6         0      binary 0/1  3297        age_cat           25 - 45  0.625399
# 7         0      binary 0/1  3297        age_cat   Greater than 45  0.424797
# 8         0      binary 0/1  3297        age_cat      Less than 25  0.738928
#
#         tnr       for       fdr       fpr       fnr       npv  precision  \
# 0  0.551532  0.349540  0.370285  0.448468  0.279853  0.650460   0.629715
# 1  0.765457  0.288125  0.408665  0.234543  0.477226  0.711875   0.591335
# 2  0.785185  0.288591  0.457895  0.214815  0.556034  0.711409   0.542105
# 3  0.852459  0.302013  0.455696  0.147541  0.676692  0.697987   0.544304
# 4  0.678212  0.242197  0.489796  0.321788  0.392713  0.757803   0.510204
# 5  0.674350  0.332029  0.365079  0.325650  0.371804  0.667971   0.634921
# 6  0.665607  0.324885  0.384736  0.334393  0.374601  0.675115   0.615264
# 7  0.830841  0.241468  0.464103  0.169159  0.575203  0.758532   0.535897
# 8  0.455371  0.426667  0.362173  0.544629  0.261072  0.573333   0.637827
#
#      pp    pn       ppr     pprev   fp    fn    tn    tp  group_label_pos  \
# 0  2174  1522  0.659387  0.588203  805   532   990  1369             1901
# 1   854  1600  0.259023  0.348003  349   461  1139   505              966
# 2   190   447  0.057628  0.298273   87   129   318   103              232
# 3    79   298  0.023961  0.209549   36    90   208    43              133
# 4   588   801  0.178344  0.423326  288   194   607   300              494
# 5  2709  3066  0.821656  0.469091  989  1018  2048  1720             2738
# 6  1913  2170  0.580224  0.468528  736   705  1465  1177             1882
# 7   390  1172  0.118289  0.249680  181   283   889   209              492
# 8   994   525  0.301486  0.654378  360   224   301   634              858
#
#    group_label_neg  group_size  total_entities      prev  ppr_disparity  \
# 0             1795        3696            7164  0.514340       2.545667
# 1             1488        2454            7164  0.393643       1.000000
# 2              405         637            7164  0.364207       0.222482
# 3              244         377            7164  0.352785       0.092506
# 4              895        1389            7164  0.355652       0.217054
# 5             3037        5775            7164  0.474113       1.000000
# 6             2201        4083            7164  0.460936       1.000000
# 7             1070        1562            7164  0.314981       0.203868
# 8              661        1519            7164  0.564845       0.519603
#
#    pprev_disparity  precision_disparity  fdr_disparity  for_disparity  \
# 0         1.690224             1.064904       0.906085       1.213154
# 1         1.000000             1.000000       1.000000       1.000000
# 2         0.857099             0.916748       1.120464       1.001616
# 3         0.602147             0.920466       1.115085       1.048203
# 4         0.902439             0.803571       1.341615       0.729447
# 5         1.000000             1.000000       1.000000       1.000000
# 6         1.000000             1.000000       1.000000       1.000000
# 7         0.532903             0.871004       1.206288       0.743241
# 8         1.396667             1.036672       0.941355       1.313286
#
#    fpr_disparity  fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0       1.912093       0.586416       1.377549       0.720526       0.913728
# 1       1.000000       1.000000       1.000000       1.000000       1.000000
# 2       0.915887       1.165140       0.849249       1.025773       0.999346
# 3       0.629057       1.417970       0.618447       1.113660       0.980490
# 4       0.988139       1.056235       0.966717       1.005728       1.134484
# 5       1.000000       1.000000       1.000000       1.000000       1.000000
# 6       1.000000       1.000000       1.000000       1.000000       1.000000
# 7       0.505868       1.535507       0.679242       1.248247       1.123560
# 8       1.628708       0.696933       1.181531       0.684144       0.849238
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0           Caucasian             Caucasian                 Caucasian
# 1           Caucasian             Caucasian                 Caucasian
# 2           Caucasian             Caucasian                 Caucasian
# 3           Caucasian             Caucasian                 Caucasian
# 4                Male                  Male                      Male
# 5                Male                  Male                      Male
# 6             25 - 45               25 - 45                   25 - 45
# 7             25 - 45               25 - 45                   25 - 45
# 8             25 - 45               25 - 45                   25 - 45
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0           Caucasian           Caucasian           Caucasian
# 1           Caucasian           Caucasian           Caucasian
# 2           Caucasian           Caucasian           Caucasian
# 3           Caucasian           Caucasian           Caucasian
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0           Caucasian           Caucasian           Caucasian
# 1           Caucasian           Caucasian           Caucasian
# 2           Caucasian           Caucasian           Caucasian
# 3           Caucasian           Caucasian           Caucasian
# 4                Male                Male                Male
# 5                Male                Male                Male
# 6             25 - 45             25 - 45             25 - 45
# 7             25 - 45             25 - 45             25 - 45
# 8             25 - 45             25 - 45             25 - 45
#
#   npv_ref_group_value  Statistical Parity  Impact Parity  FDR Parity  \
# 0           Caucasian               False          False        True
# 1           Caucasian                True           True        True
# 2           Caucasian               False           True        True
# 3           Caucasian               False          False        True
# 4                Male               False           True       False
# 5                Male                True           True        True
# 6             25 - 45                True           True        True
# 7             25 - 45               False          False        True
# 8             25 - 45               False          False        True
#
#    FPR Parity  FOR Parity  FNR Parity  TPR Parity  TNR Parity  NPV Parity  \
# 0       False        True       False       False       False        True
# 1        True        True        True        True        True        True
# 2        True        True        True        True        True        True
# 3       False        True       False       False        True        True
# 4        True       False        True        True        True        True
# 5        True        True        True        True        True        True
# 6        True        True        True        True        True        True
# 7       False       False       False       False        True        True
# 8       False       False       False        True       False        True
#
#    Precision Parity  TypeI Parity  TypeII Parity  Equalized Odds  \
# 0              True         False          False           False
# 1              True          True           True            True
# 2              True          True           True            True
# 3              True         False          False           False
# 4              True         False          False            True
# 5              True          True           True            True
# 6              True          True           True            True
# 7              True         False          False           False
# 8              True         False          False           False
#
#    Unsupervised Fairness  Supervised Fairness
# 0                  False                False
# 1                   True                 True
# 2                  False                 True
# 3                  False                False
# 4                  False                False
# 5                   True                 True
# 6                   True                 True
# 7                  False                False
# 8                  False                False

# %%
overall_fairness = fairness.get_overall_fairness(fairness_df)
print(overall_fairness)
# Out:
# {'Unsupervised Fairness': False, 'Supervised Fairness': False, 'Overall Fairness': False}

# %%
metrics = ['fpr', 'fnr', 'for']
disparity_tolerance = 1.25

ap.summary(bias_df, metrics, fairness_threshold=disparity_tolerance)
# Out:
# alt.VConcatChart(...)
